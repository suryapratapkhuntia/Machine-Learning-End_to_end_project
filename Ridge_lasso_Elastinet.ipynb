# %% [markdown]
# <a href="https://colab.research.google.com/github/suryapratapkhuntia/Machine-Learning-End_to_end_project/blob/main/Ridge_lasso_Elastinet.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score

# %%
df=pd.read_csv("/content/cars_data.csv")
df.sample(5)
# Out:
#               Make      Model  Year             Engine Fuel Type  Engine HP  \
# 3550  Aston Martin        DBS  2012  premium unleaded (required)      510.0
# 9720       Hyundai     Sonata  2015             regular unleaded      245.0
# 875           Saab       9-7X  2009             regular unleaded      390.0
# 7473    Volkswagen     Passat  2016             regular unleaded      170.0
# 3242      Cadillac  CTS Wagon  2014             regular unleaded      318.0
#
#       Engine Cylinders Transmission Type      Driven_Wheels  Number of Doors  \
# 3550              12.0            MANUAL   rear wheel drive              2.0
# 9720               4.0         AUTOMATIC  front wheel drive              4.0
# 875                8.0         AUTOMATIC    all wheel drive              4.0
# 7473               4.0         AUTOMATIC  front wheel drive              4.0
# 3242               6.0         AUTOMATIC    all wheel drive              4.0
#
# ...

# %%
x_train,x_test,y_train,y_test=train_test_split(df.drop('MSRP',axis=1),df['MSRP'],test_size=0.2)
x_train.shape
# Out:
# (9531, 15)

# %%
from sklearn.linear_model import Ridge
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer


categorical_features = x_train.select_dtypes(include=['object']).columns
numerical_features = x_train.select_dtypes(include=np.number).columns


preprocessor = ColumnTransformer(
    transformers=[
        ('num', SimpleImputer(strategy='mean'), numerical_features),
        ('cat', OneHotEncoder(handle_unknown='ignore'), categorical_features)
    ],
    remainder='passthrough'
)


pipeline = Pipeline(steps=[('preprocessor', preprocessor),
                           ('regressor', Ridge(alpha=1))])


pipeline.fit(x_train, y_train)


y_pred = pipeline.predict(x_test)

from sklearn.metrics import r2_score
r2 = r2_score(y_test, y_pred)

print(f"R-squared score: {r2}")
# Out:
# R-squared score: 0.9391978628442295

# %%
import sklearn.linear_model as lm
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer


categorical_features = x_train.select_dtypes(include=['object']).columns
numerical_features = x_train.select_dtypes(include=np.number).columns


preprocessor = ColumnTransformer(
    transformers=[
        ('num', SimpleImputer(strategy='mean'), numerical_features),
        ('cat', OneHotEncoder(handle_unknown='ignore'), categorical_features)
    ],
    remainder='passthrough'
)


pipeline = Pipeline(steps=[('preprocessor', preprocessor),
                           ('regressor', lm.Lasso(alpha=1, max_iter=10000))])


pipeline.fit(x_train, y_train)


y_pred = pipeline.predict(x_test)

from sklearn.metrics import r2_score
r2 = r2_score(y_test, y_pred)

print(f"R-squared score: {r2}")
# Out:
# R-squared score: 0.949990323108693

# %%
from sklearn.linear_model import ElasticNet
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer


categorical_features = x_train.select_dtypes(include=['object']).columns
numerical_features = x_train.select_dtypes(include=np.number).columns


preprocessor = ColumnTransformer(
    transformers=[
        ('num', SimpleImputer(strategy='mean'), numerical_features),
        ('cat', OneHotEncoder(handle_unknown='ignore'), categorical_features)
    ],
    remainder='passthrough'
)


pipeline = Pipeline(steps=[('preprocessor', preprocessor),
                           ('regressor', ElasticNet(l1_ratio=0.5))])


pipeline.fit(x_train, y_train)


y_pred = pipeline.predict(x_test)

from sklearn.metrics import r2_score
r2 = r2_score(y_test, y_pred)

print(f"R-squared score: {r2}")
# Out:
# R-squared score: 0.6293382651193429
