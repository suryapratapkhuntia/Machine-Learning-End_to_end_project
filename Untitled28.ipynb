# %% [markdown]
# <a href="https://colab.research.google.com/github/suryapratapkhuntia/Machine-Learning-End_to_end_project/blob/main/Untitled28.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split

# %%
df=pd.read_csv("/content/archive (2).zip")
df
# Out:
#     Unnamed: 0  cgpa     iq  placement
# 0            0   6.8  123.0          1
# 1            1   5.9  106.0          0
# 2            2   5.3  121.0          0
# 3            3   7.4  132.0          1
# 4            4   5.8  142.0          0
# ..         ...   ...    ...        ...
# 95          95   4.3  200.0          0
# 96          96   4.4   42.0          0
# 97          97   6.7  182.0          1
# 98          98   6.3  103.0          1
# 99          99   6.2  113.0          1
#
# [100 rows x 4 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  100 non-null    int64
#  1   cgpa        100 non-null    float64
#  2   iq          100 non-null    float64
#  3   placement   100 non-null    int64
# dtypes: float64(2), int64(2)
# memory usage: 3.3 KB

# %%
df.shape
# Out:
# (100, 4)

# %%
df=df.iloc[:,1:]

# %%
df.head()
# Out:
#    cgpa     iq  placement
# 0   6.8  123.0          1
# 1   5.9  106.0          0
# 2   5.3  121.0          0
# 3   7.4  132.0          1
# 4   5.8  142.0          0

# %%
df.head()
# Out:
#    Unnamed: 0  cgpa     iq  placement
# 0           0   6.8  123.0          1
# 1           1   5.9  106.0          0
# 2           2   5.3  121.0          0
# 3           3   7.4  132.0          1
# 4           4   5.8  142.0          0

# %%
#steps

# 0 preprocess + EDA + feature selection
# 1.Extract input and output cols
# 2.Scale the values
# 3.Train test split
# 4.Train the model
# 5.Evaluate the model/model selection
# 6.Deploy the model

# %%
sns.scatterplot(x=df["cgpa"], y=df["iq"], hue=df['placement'])
plt.show()

# %%
# if you saw a line can separate two parts then use logistic regression

# %%
x=df.iloc[:,0:2]
y=df.iloc[:,-1:]
x
# Out:
#     cgpa     iq
# 0    6.8  123.0
# 1    5.9  106.0
# 2    5.3  121.0
# 3    7.4  132.0
# 4    5.8  142.0
# ..   ...    ...
# 95   4.3  200.0
# 96   4.4   42.0
# 97   6.7  182.0
# 98   6.3  103.0
# 99   6.2  113.0
#
# [100 rows x 2 columns]

# %%
y
# Out:
#     placement
# 0           1
# 1           0
# 2           0
# 3           1
# 4           0
# ..        ...
# 95          0
# 96          0
# 97          1
# 98          1
# 99          1
#
# [100 rows x 1 columns]

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.4)

# %%
from sklearn.preprocessing import StandardScaler

# %%
scalar=StandardScaler()

# %%
x_train = scalar.fit_transform(x_train)
x_train
# Out:
# array([[-0.25101891,  0.47311938],
#        [-0.52320808,  0.28574537],
#        [ 1.01919724, -1.75194702],
#        [ 1.92649449,  1.01181967],
#        [-0.70466753,  0.21548012],
#        [ 0.92846752,  0.37943238],
#        [ 0.74700807,  0.00468435],
#        [-1.06758643, -0.25295492],
#        [ 1.20065669, -1.70510352],
#        [ 0.38408917, -0.15926791],
#        [ 0.74700807, -0.25295492],
#        [ 0.11189999, -0.97902922],
#        [-0.61393781, -0.04215915],
#        [-0.97685671,  1.71447222],
#        [ 1.47284587, -0.79165521],
#        [-0.16028918,  0.44969763],
#        [-0.70466753,  2.37028127],
#        [-2.42853231,  1.40998945],
#        [-0.06955946, -0.39348543],
#        [ 0.56554862,  0.35601063],
#        [ 0.83773779, -0.62770294],
#        [-1.43050533, -1.89247753],
#        [ 0.56554862, -0.0655809 ],
#        [-0.25101891,  0.40285413],
#        [ 1.38211614,  0.82444566],
#        [ 0.29335944,  0.12179311],
#        [-0.88612698, -0.7448117 ],
# ...

# %%
x_test = scalar.transform(x_test)
x_test
# Out:
# array([[-1.88415396, -0.32322017],
#        [ 0.92846752, -0.25295492],
#        [ 1.65430532, -0.20611141],
#        [-1.06758643,  1.08208493],
#        [-1.06758643,  0.42627588],
#        [ 0.74700807, -0.76823345],
#        [-1.15831616, -0.04215915],
#        [ 0.92846752, -1.377199  ],
#        [-0.97685671,  0.7541804 ],
#        [ 0.65627834,  1.3865677 ],
#        [-1.43050533,  0.61364989],
#        [ 1.83576477, -1.02587272],
#        [ 0.11189999,  0.21548012],
#        [-0.16028918,  1.01181967],
#        [ 0.92846752,  1.78473748],
#        [-0.70466753, -0.76823345],
#        [ 0.02117027, -0.48717243],
#        [-1.06758643,  0.94155442],
#        [ 0.47481889,  0.87128916],
#        [-0.70466753,  0.89471091],
#        [ 1.38211614,  0.16863661],
#        [ 0.11189999, -0.46375068],
#        [-1.79342423, -1.11955973],
#        [ 0.02117027, -1.82221228],
#        [-0.25101891,  0.21548012],
#        [-1.15831616, -0.83849871],
#        [ 2.28941339, -0.0655809 ],
# ...

# %%
from sklearn.linear_model import LogisticRegression

# %%
clf=LogisticRegression()

# %%
clf.fit(x_train,y_train)
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# LogisticRegression()

# %%
y_pred = clf.predict(x_test)

# %%
y_test
# Out:
#     placement
# 31          0
# 29          1
# 55          1
# 75          0
# 51          0
# 35          1
# 24          0
# 64          1
# 76          0
# 97          1
# 88          0
# 58          1
# 71          1
# 85          1
# 26          1
# 28          0
# 62          0
# 34          0
# 38          1
# 47          0
# 83          1
# 14          0
# 68          0
# 10          1
# 87          1
# 23          0
# 69          1
# 15          0
# 84          0
# 70          1
# 61          1
# 81          0
# 39          0
# 67          0
# 72          1
# 44          1
# 92          0
# 3           1
# 30          1
# 99          1

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(y_test,y_pred)
# Out:
# 0.925

# %%
# seeing the line graph which is plotted

# %%
from mlxtend.plotting import plot_decision_regions

# %%
plot_decision_regions(x_train,y_train.values.ravel(),clf=clf,legend=2)
plt.show()

# %%
import pickle

# %%
pickle.dump(clf,open('model.pkl','wb'))

# %%
import pickle

# Save the trained model to a file
filename = 'model.pkl'
pickle.dump(clf, open(filename, 'wb'))

print(f"Model saved to {filename}")
# Out:
# Model saved to model.pkl
